# %%
import os
import json
import time
import copy
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.amp import autocast, GradScaler
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms

from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    matthews_corrcoef,
    balanced_accuracy_score,
    confusion_matrix,
    classification_report
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
SEED = 2912

def seed_everything(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

seed_everything()
torch.backends.cudnn.benchmark = True

# %%
DATASET_PATH = "../Dataset"
DATASET_NAME = "Mendeley_Dataset"

IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 100
LR = 1e-4
ACCUM_STEPS = 2
PATIENCE = 15
MIN_DELTA = 0.001

OUTPUT_DIR = f"../Results/{DATASET_NAME}/Model_3"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.7, 0.8)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(40),
    transforms.ToTensor()
])

val_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor()
])

# %%
full_dataset = datasets.ImageFolder(f"{DATASET_PATH}/{DATASET_NAME}")

class_names = full_dataset.classes
num_classes = len(class_names)

train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_dataset.dataset.transform = train_transform
val_dataset.dataset.transform = val_transform

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

print(class_names)
print(num_classes)
# Out:
# ['Bacteria', 'Fungi', 'Healthy', 'Nematode', 'Pest', 'Phytopthora', 'Virus']
# 7

# %%
class AFpM(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return x * torch.sigmoid(x) + 0.1 * torch.tanh(x)


class CrossAttention(nn.Module):
    def __init__(self, dim):
        super().__init__()

        self.scale = dim ** -0.5

        self.query = nn.Linear(dim, dim)
        self.key = nn.Linear(dim, dim)
        self.value = nn.Linear(dim, dim)

    def forward(self, q_input, kv_input):

        Q = self.query(q_input)
        K = self.key(kv_input)
        V = self.value(kv_input)

        attn = torch.softmax(
            torch.matmul(Q.unsqueeze(1), K.unsqueeze(2)) * self.scale,
            dim=-1
        )

        out = torch.matmul(attn, V.unsqueeze(1)).squeeze(1)

        return out


class ParallelLightCNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.afpm = AFpM()

        self.features = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            # nn.ReLU(),
            AFpM(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            # nn.ReLU(),
            AFpM(),
            nn.MaxPool2d(2)
        )

        self.gap = nn.AdaptiveAvgPool2d(1)

        self.fc1 = nn.Sequential(
            nn.Linear(64, 128),
            nn.BatchNorm1d(128),
            # nn.ReLU(),
            AFpM(),
            nn.Dropout(0.6)
        )

        self.fc2 = nn.Sequential(
            nn.Linear(64, 128),
            nn.BatchNorm1d(128),
            # nn.ReLU(),
            AFpM(),
            nn.Dropout(0.6)
        )

        self.cross_attention = CrossAttention(128)

        self.classifier = nn.Linear(384, num_classes)

    def forward(self, x):

        x = self.features(x)
        x = self.gap(x).flatten(1)

        b1 = self.fc1(x)
        b2 = self.fc2(x)

        attn_out = self.cross_attention(b1, b2)

        fused = torch.cat([b1, b2, attn_out], dim=1)

        return self.classifier(fused)


model = ParallelLightCNN(num_classes).to(device)

params = sum(p.numel() for p in model.parameters())
print(f"Parameters: {params:,}")
# Out:
# Parameters: 88,967

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=LR)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.2,
    patience=3
)

scaler = GradScaler()

# %%
def evaluate(model, loader):
    model.eval()

    all_preds = []
    all_labels = []
    total_loss = 0

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)

            with autocast(device_type=device.type):
                outputs = model(images)
                loss = criterion(outputs, labels)

            total_loss += loss.item()

            preds = outputs.argmax(1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)

    return total_loss/len(loader), acc, all_labels, all_preds

# %%
history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": []
}

best_acc = 0
best_weights = copy.deepcopy(model.state_dict())
early_counter = 0

# %%
for epoch in range(EPOCHS):

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    optimizer.zero_grad()

    for i, (images, labels) in enumerate(train_loader):

        images, labels = images.to(device), labels.to(device)

        with autocast(device_type=device.type):
            outputs = model(images)
            loss = criterion(outputs, labels) / ACCUM_STEPS

        scaler.scale(loss).backward()

        if (i+1) % ACCUM_STEPS == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        running_loss += loss.item()*ACCUM_STEPS

        preds = outputs.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = running_loss / len(train_loader)
    train_acc = correct / total

    val_loss, val_acc, _, _ = evaluate(model, val_loader)

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)
    
    print("-"*30)
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"LR: {optimizer.param_groups[0]['lr']:.2e}")
    print(f"Early Counter: {early_counter} | Best Val Acc: {best_acc:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")
    print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    print("-"*30)

    if val_acc > best_acc + MIN_DELTA:
        best_acc = val_acc
        best_weights = copy.deepcopy(model.state_dict())
        torch.save(best_weights, f"{OUTPUT_DIR}/best_model.pth")
        early_counter = 0
    else:
        early_counter += 1

    if early_counter >= PATIENCE:
        print("Early stopping")
        break
# Out:
# ------------------------------
# Epoch 1/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.0000
# Train Acc: 0.2317 | Val Acc: 0.4026
# Train Loss: 1.9130 | Val Loss: 1.7289
# ------------------------------
# ------------------------------
# Epoch 2/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.4026
# Train Acc: 0.3341 | Val Acc: 0.4286
# Train Loss: 1.7440 | Val Loss: 1.6294
# ------------------------------
# ------------------------------
# Epoch 3/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.4286
# Train Acc: 0.3817 | Val Acc: 0.4318
# Train Loss: 1.6693 | Val Loss: 1.5764
# ------------------------------
# ------------------------------
# Epoch 4/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.4318
# Train Acc: 0.3854 | Val Acc: 0.4481
# Train Loss: 1.6263 | Val Loss: 1.5362
# ------------------------------
# ------------------------------
# Epoch 5/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.4481
# Train Acc: 0.4138 | Val Acc: 0.4821
# Train Loss: 1.5850 | Val Loss: 1.4984
# ------------------------------
# ------------------------------
# Epoch 6/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.4821
# Train Acc: 0.4244 | Val Acc: 0.4870
# Train Loss: 1.5515 | Val Loss: 1.4818
# ------------------------------
# ------------------------------
# Epoch 7/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.4870
# Train Acc: 0.4146 | Val Acc: 0.4838
# Train Loss: 1.5326 | Val Loss: 1.4483
# ------------------------------
# ------------------------------
# Epoch 8/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.4870
# Train Acc: 0.4268 | Val Acc: 0.5000
# Train Loss: 1.4979 | Val Loss: 1.4232
# ------------------------------
# ------------------------------
# Epoch 9/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5000
# Train Acc: 0.4472 | Val Acc: 0.5000
# Train Loss: 1.4677 | Val Loss: 1.4210
# ------------------------------
# ------------------------------
# Epoch 10/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.5000
# Train Acc: 0.4423 | Val Acc: 0.5244
# Train Loss: 1.4688 | Val Loss: 1.3925
# ------------------------------
# ------------------------------
# Epoch 11/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5244
# Train Acc: 0.4427 | Val Acc: 0.5146
# Train Loss: 1.4499 | Val Loss: 1.3845
# ------------------------------
# ------------------------------
# Epoch 12/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.5244
# Train Acc: 0.4581 | Val Acc: 0.5227
# Train Loss: 1.4311 | Val Loss: 1.3585
# ------------------------------
# ------------------------------
# Epoch 13/100
# LR: 1.00e-04
# Early Counter: 2 | Best Val Acc: 0.5244
# Train Acc: 0.4411 | Val Acc: 0.5373
# Train Loss: 1.4251 | Val Loss: 1.3258
# ------------------------------
# ------------------------------
# Epoch 14/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5373
# Train Acc: 0.4598 | Val Acc: 0.5455
# Train Loss: 1.4052 | Val Loss: 1.3429
# ------------------------------
# ------------------------------
# Epoch 15/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5455
# Train Acc: 0.4715 | Val Acc: 0.5341
# Train Loss: 1.3796 | Val Loss: 1.3111
# ------------------------------
# ------------------------------
# Epoch 16/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.5455
# Train Acc: 0.4724 | Val Acc: 0.5471
# Train Loss: 1.3722 | Val Loss: 1.2821
# ------------------------------
# ------------------------------
# Epoch 17/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5471
# Train Acc: 0.4858 | Val Acc: 0.5503
# Train Loss: 1.3569 | Val Loss: 1.3100
# ------------------------------
# ------------------------------
# Epoch 18/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5503
# Train Acc: 0.4858 | Val Acc: 0.5422
# Train Loss: 1.3515 | Val Loss: 1.2767
# ------------------------------
# ------------------------------
# Epoch 19/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.5503
# Train Acc: 0.4935 | Val Acc: 0.5390
# Train Loss: 1.3244 | Val Loss: 1.2894
# ------------------------------
# ------------------------------
# Epoch 20/100
# LR: 1.00e-04
# Early Counter: 2 | Best Val Acc: 0.5503
# Train Acc: 0.4963 | Val Acc: 0.5666
# Train Loss: 1.3244 | Val Loss: 1.2521
# ------------------------------
# ------------------------------
# Epoch 21/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5666
# Train Acc: 0.4898 | Val Acc: 0.5568
# Train Loss: 1.3157 | Val Loss: 1.2500
# ------------------------------
# ------------------------------
# Epoch 22/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.5666
# Train Acc: 0.4972 | Val Acc: 0.5747
# Train Loss: 1.3102 | Val Loss: 1.2357
# ------------------------------
# ------------------------------
# Epoch 23/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5747
# Train Acc: 0.5045 | Val Acc: 0.5649
# Train Loss: 1.2996 | Val Loss: 1.2304
# ------------------------------
# ------------------------------
# Epoch 24/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.5747
# Train Acc: 0.5045 | Val Acc: 0.5698
# Train Loss: 1.2861 | Val Loss: 1.2212
# ------------------------------
# ------------------------------
# Epoch 25/100
# LR: 1.00e-04
# Early Counter: 2 | Best Val Acc: 0.5747
# Train Acc: 0.5057 | Val Acc: 0.5731
# Train Loss: 1.2757 | Val Loss: 1.2195
# ------------------------------
# ------------------------------
# Epoch 26/100
# LR: 1.00e-04
# Early Counter: 3 | Best Val Acc: 0.5747
# Train Acc: 0.5207 | Val Acc: 0.5828
# Train Loss: 1.2730 | Val Loss: 1.2084
# ------------------------------
# ------------------------------
# Epoch 27/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5828
# Train Acc: 0.5110 | Val Acc: 0.5747
# Train Loss: 1.2623 | Val Loss: 1.2172
# ------------------------------
# ------------------------------
# Epoch 28/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.5828
# Train Acc: 0.5215 | Val Acc: 0.5828
# Train Loss: 1.2664 | Val Loss: 1.1962
# ------------------------------
# ------------------------------
# Epoch 29/100
# LR: 1.00e-04
# Early Counter: 2 | Best Val Acc: 0.5828
# Train Acc: 0.5285 | Val Acc: 0.5747
# Train Loss: 1.2435 | Val Loss: 1.2035
# ------------------------------
# ------------------------------
# Epoch 30/100
# LR: 1.00e-04
# Early Counter: 3 | Best Val Acc: 0.5828
# Train Acc: 0.5187 | Val Acc: 0.5828
# Train Loss: 1.2512 | Val Loss: 1.2019
# ------------------------------
# ------------------------------
# Epoch 31/100
# LR: 1.00e-04
# Early Counter: 4 | Best Val Acc: 0.5828
# Train Acc: 0.5285 | Val Acc: 0.5893
# Train Loss: 1.2352 | Val Loss: 1.1721
# ------------------------------
# ------------------------------
# Epoch 32/100
# LR: 1.00e-04
# Early Counter: 0 | Best Val Acc: 0.5893
# Train Acc: 0.5321 | Val Acc: 0.5860
# Train Loss: 1.2181 | Val Loss: 1.1972
# ------------------------------
# ------------------------------
# Epoch 33/100
# LR: 1.00e-04
# Early Counter: 1 | Best Val Acc: 0.5893
# Train Acc: 0.5366 | Val Acc: 0.5893
# Train Loss: 1.2239 | Val Loss: 1.1813
# ------------------------------
# ------------------------------
# Epoch 34/100
# LR: 1.00e-04
# Early Counter: 2 | Best Val Acc: 0.5893
# Train Acc: 0.5297 | Val Acc: 0.5844
# Train Loss: 1.2244 | Val Loss: 1.1861
# ------------------------------
# ------------------------------
# Epoch 35/100
# LR: 2.00e-05
# Early Counter: 3 | Best Val Acc: 0.5893
# Train Acc: 0.5341 | Val Acc: 0.5812
# Train Loss: 1.2315 | Val Loss: 1.2208
# ------------------------------
# ------------------------------
# Epoch 36/100
# LR: 2.00e-05
# Early Counter: 4 | Best Val Acc: 0.5893
# Train Acc: 0.5350 | Val Acc: 0.5942
# Train Loss: 1.1900 | Val Loss: 1.1477
# ------------------------------
# ------------------------------
# Epoch 37/100
# LR: 2.00e-05
# Early Counter: 0 | Best Val Acc: 0.5942
# Train Acc: 0.5569 | Val Acc: 0.5990
# Train Loss: 1.1733 | Val Loss: 1.1418
# ------------------------------
# ------------------------------
# Epoch 38/100
# LR: 2.00e-05
# Early Counter: 0 | Best Val Acc: 0.5990
# Train Acc: 0.5516 | Val Acc: 0.6023
# Train Loss: 1.1800 | Val Loss: 1.1473
# ------------------------------
# ------------------------------
# Epoch 39/100
# LR: 2.00e-05
# Early Counter: 0 | Best Val Acc: 0.6023
# Train Acc: 0.5354 | Val Acc: 0.6006
# Train Loss: 1.1974 | Val Loss: 1.1417
# ------------------------------
# ------------------------------
# Epoch 40/100
# LR: 2.00e-05
# Early Counter: 1 | Best Val Acc: 0.6023
# Train Acc: 0.5467 | Val Acc: 0.5942
# Train Loss: 1.1887 | Val Loss: 1.1437
# ------------------------------
# ------------------------------
# Epoch 41/100
# LR: 2.00e-05
# Early Counter: 2 | Best Val Acc: 0.6023
# Train Acc: 0.5516 | Val Acc: 0.5974
# Train Loss: 1.1686 | Val Loss: 1.1409
# ------------------------------
# ------------------------------
# Epoch 42/100
# LR: 2.00e-05
# Early Counter: 3 | Best Val Acc: 0.6023
# Train Acc: 0.5589 | Val Acc: 0.5990
# Train Loss: 1.1786 | Val Loss: 1.1399
# ------------------------------
# ------------------------------
# Epoch 43/100
# LR: 2.00e-05
# Early Counter: 4 | Best Val Acc: 0.6023
# Train Acc: 0.5504 | Val Acc: 0.6023
# Train Loss: 1.1867 | Val Loss: 1.1374
# ------------------------------
# ------------------------------
# Epoch 44/100
# LR: 2.00e-05
# Early Counter: 5 | Best Val Acc: 0.6023
# Train Acc: 0.5524 | Val Acc: 0.5974
# Train Loss: 1.1806 | Val Loss: 1.1395
# ------------------------------
# ------------------------------
# Epoch 45/100
# LR: 2.00e-05
# Early Counter: 6 | Best Val Acc: 0.6023
# Train Acc: 0.5463 | Val Acc: 0.6055
# Train Loss: 1.1740 | Val Loss: 1.1298
# ------------------------------
# ------------------------------
# Epoch 46/100
# LR: 2.00e-05
# Early Counter: 0 | Best Val Acc: 0.6055
# Train Acc: 0.5646 | Val Acc: 0.5925
# Train Loss: 1.1663 | Val Loss: 1.1445
# ------------------------------
# ------------------------------
# Epoch 47/100
# LR: 2.00e-05
# Early Counter: 1 | Best Val Acc: 0.6055
# Train Acc: 0.5500 | Val Acc: 0.5958
# Train Loss: 1.1701 | Val Loss: 1.1327
# ------------------------------
# ------------------------------
# Epoch 48/100
# LR: 2.00e-05
# Early Counter: 2 | Best Val Acc: 0.6055
# Train Acc: 0.5663 | Val Acc: 0.6006
# Train Loss: 1.1639 | Val Loss: 1.1275
# ------------------------------
# ------------------------------
# Epoch 49/100
# LR: 2.00e-05
# Early Counter: 3 | Best Val Acc: 0.6055
# Train Acc: 0.5488 | Val Acc: 0.6023
# Train Loss: 1.1674 | Val Loss: 1.1207
# ------------------------------
# ------------------------------
# Epoch 50/100
# LR: 2.00e-05
# Early Counter: 4 | Best Val Acc: 0.6055
# Train Acc: 0.5565 | Val Acc: 0.5877
# Train Loss: 1.1729 | Val Loss: 1.1331
# ------------------------------
# ------------------------------
# Epoch 51/100
# LR: 2.00e-05
# Early Counter: 5 | Best Val Acc: 0.6055
# Train Acc: 0.5606 | Val Acc: 0.6023
# Train Loss: 1.1709 | Val Loss: 1.1263
# ------------------------------
# ------------------------------
# Epoch 52/100
# LR: 2.00e-05
# Early Counter: 6 | Best Val Acc: 0.6055
# Train Acc: 0.5533 | Val Acc: 0.5942
# Train Loss: 1.1617 | Val Loss: 1.1323
# ------------------------------
# ------------------------------
# Epoch 53/100
# LR: 4.00e-06
# Early Counter: 7 | Best Val Acc: 0.6055
# Train Acc: 0.5549 | Val Acc: 0.6039
# Train Loss: 1.1749 | Val Loss: 1.1312
# ------------------------------
# ------------------------------
# Epoch 54/100
# LR: 4.00e-06
# Early Counter: 8 | Best Val Acc: 0.6055
# Train Acc: 0.5654 | Val Acc: 0.6039
# Train Loss: 1.1524 | Val Loss: 1.1247
# ------------------------------
# ------------------------------
# Epoch 55/100
# LR: 4.00e-06
# Early Counter: 9 | Best Val Acc: 0.6055
# Train Acc: 0.5589 | Val Acc: 0.5990
# Train Loss: 1.1557 | Val Loss: 1.1178
# ------------------------------
# ------------------------------
# Epoch 56/100
# LR: 4.00e-06
# Early Counter: 10 | Best Val Acc: 0.6055
# Train Acc: 0.5634 | Val Acc: 0.6055
# Train Loss: 1.1583 | Val Loss: 1.1250
# ------------------------------
# ------------------------------
# Epoch 57/100
# LR: 4.00e-06
# Early Counter: 11 | Best Val Acc: 0.6055
# Train Acc: 0.5663 | Val Acc: 0.6006
# Train Loss: 1.1497 | Val Loss: 1.1256
# ------------------------------
# ------------------------------
# Epoch 58/100
# LR: 4.00e-06
# Early Counter: 12 | Best Val Acc: 0.6055
# Train Acc: 0.5642 | Val Acc: 0.6120
# Train Loss: 1.1543 | Val Loss: 1.1229
# ------------------------------
# ------------------------------
# Epoch 59/100
# LR: 8.00e-07
# Early Counter: 0 | Best Val Acc: 0.6120
# Train Acc: 0.5634 | Val Acc: 0.6039
# Train Loss: 1.1689 | Val Loss: 1.1223
# ------------------------------
# ------------------------------
# Epoch 60/100
# LR: 8.00e-07
# Early Counter: 1 | Best Val Acc: 0.6120
# Train Acc: 0.5585 | Val Acc: 0.6120
# Train Loss: 1.1597 | Val Loss: 1.1221
# ------------------------------
# ------------------------------
# Epoch 61/100
# LR: 8.00e-07
# Early Counter: 2 | Best Val Acc: 0.6120
# Train Acc: 0.5634 | Val Acc: 0.6071
# Train Loss: 1.1498 | Val Loss: 1.1240
# ------------------------------
# ------------------------------
# Epoch 62/100
# LR: 8.00e-07
# Early Counter: 3 | Best Val Acc: 0.6120
# Train Acc: 0.5569 | Val Acc: 0.6088
# Train Loss: 1.1593 | Val Loss: 1.1282
# ------------------------------
# ------------------------------
# Epoch 63/100
# LR: 1.60e-07
# Early Counter: 4 | Best Val Acc: 0.6120
# Train Acc: 0.5593 | Val Acc: 0.6023
# Train Loss: 1.1539 | Val Loss: 1.1211
# ------------------------------
# ------------------------------
# Epoch 64/100
# LR: 1.60e-07
# Early Counter: 5 | Best Val Acc: 0.6120
# Train Acc: 0.5622 | Val Acc: 0.6039
# Train Loss: 1.1526 | Val Loss: 1.1208
# ------------------------------
# ------------------------------
# Epoch 65/100
# LR: 1.60e-07
# Early Counter: 6 | Best Val Acc: 0.6120
# Train Acc: 0.5553 | Val Acc: 0.6104
# Train Loss: 1.1595 | Val Loss: 1.1213
# ------------------------------
# ------------------------------
# Epoch 66/100
# LR: 1.60e-07
# Early Counter: 7 | Best Val Acc: 0.6120
# Train Acc: 0.5593 | Val Acc: 0.6055
# Train Loss: 1.1624 | Val Loss: 1.1204
# ------------------------------
# ------------------------------
# Epoch 67/100
# LR: 3.20e-08
# Early Counter: 8 | Best Val Acc: 0.6120
# Train Acc: 0.5654 | Val Acc: 0.6006
# Train Loss: 1.1581 | Val Loss: 1.1223
# ------------------------------
# ------------------------------
# Epoch 68/100
# LR: 3.20e-08
# Early Counter: 9 | Best Val Acc: 0.6120
# Train Acc: 0.5720 | Val Acc: 0.6055
# Train Loss: 1.1306 | Val Loss: 1.1242
# ------------------------------
# ------------------------------
# Epoch 69/100
# LR: 3.20e-08
# Early Counter: 10 | Best Val Acc: 0.6120
# Train Acc: 0.5646 | Val Acc: 0.6088
# Train Loss: 1.1585 | Val Loss: 1.1268
# ------------------------------
# ------------------------------
# Epoch 70/100
# LR: 3.20e-08
# Early Counter: 11 | Best Val Acc: 0.6120
# Train Acc: 0.5675 | Val Acc: 0.6071
# Train Loss: 1.1563 | Val Loss: 1.1235
# ------------------------------
# ------------------------------
# Epoch 71/100
# LR: 6.40e-09
# Early Counter: 12 | Best Val Acc: 0.6120
# Train Acc: 0.5504 | Val Acc: 0.6023
# Train Loss: 1.1637 | Val Loss: 1.1225
# ------------------------------
# ------------------------------
# Epoch 72/100
# LR: 6.40e-09
# Early Counter: 13 | Best Val Acc: 0.6120
# Train Acc: 0.5650 | Val Acc: 0.6055
# Train Loss: 1.1549 | Val Loss: 1.1231
# ------------------------------
# ------------------------------
# Epoch 73/100
# LR: 6.40e-09
# Early Counter: 14 | Best Val Acc: 0.6120
# Train Acc: 0.5711 | Val Acc: 0.6104
# Train Loss: 1.1610 | Val Loss: 1.1234
# ------------------------------
# Early stopping

# %%
model.load_state_dict(best_weights)

val_loss, val_acc, y_true, y_pred = evaluate(model, val_loader)

# %%
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average='weighted'
)

mcc = matthews_corrcoef(y_true, y_pred)
bal_acc = balanced_accuracy_score(y_true, y_pred)

cm = confusion_matrix(y_true, y_pred)

report = classification_report(
    y_true,
    y_pred,
    target_names=class_names
)

results = {
    "accuracy": val_acc,
    "precision": precision,
    "recall": recall,
    "f1": f1,
    "mcc": mcc,
    "balanced_accuracy": bal_acc
}

print(results)
print(report)
# Out:
# {'accuracy': 0.612012987012987, 'precision': 0.5966008598347947, 'recall': 0.612012987012987, 'f1': 0.6000353517503394, 'mcc': 0.5250945971992137, 'balanced_accuracy': 0.5701957043592484}
#               precision    recall  f1-score   support
#
#     Bacteria       0.78      0.90      0.84       126
#        Fungi       0.52      0.51      0.51       139
#      Healthy       0.35      0.14      0.20        42
#     Nematode       0.64      0.64      0.64        11
#         Pest       0.50      0.53      0.51       112
#  Phytopthora       0.64      0.59      0.61        71
#        Virus       0.65      0.68      0.66       115
#
#     accuracy                           0.61       616
#    macro avg       0.58      0.57      0.57       616
# weighted avg       0.60      0.61      0.60       616

# %%
pd.DataFrame(history).to_csv(f"{OUTPUT_DIR}/history.csv", index=False)
pd.DataFrame([results]).to_csv(f"{OUTPUT_DIR}/summary.csv", index=False)

with open(f"{OUTPUT_DIR}/results.json","w") as f:
    json.dump(results,f,indent=4)

with open(f"{OUTPUT_DIR}/report.txt","w") as f:
    f.write(report)

# %%
plt.figure(figsize=(12,5))
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"], label="Val")
plt.legend()
plt.savefig(f"{OUTPUT_DIR}/loss_curve.png")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"], label="Val")
plt.legend()
plt.savefig(f"{OUTPUT_DIR}/acc_curve.png")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.savefig(f"{OUTPUT_DIR}/confusion_matrix.png")
plt.show()
